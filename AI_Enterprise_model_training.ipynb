# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('seeds.csv')

# %%
data
# Out:
#       Area  Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# 0    15.26      14.84       0.8710          5.763         3.312
# 1    14.88      14.57       0.8811          5.554         3.333
# 2    14.29      14.09       0.9050          5.291         3.337
# 3    13.84      13.94       0.8955          5.324         3.379
# 4    16.14      14.99       0.9034          5.658         3.562
# ..     ...        ...          ...            ...           ...
# 194  12.19      13.20       0.8783          5.137         2.981
# 195  11.23      12.88       0.8511          5.140         2.795
# 196  13.20      13.66       0.8883          5.236         3.232
# 197  11.84      13.21       0.8521          5.175         2.836
# 198  12.30      13.34       0.8684          5.243         2.974
#
#      Asymmetry.Coeff  Kernel.Groove  Type
# 0              2.221          5.220     1
# 1              1.018          4.956     1
# 2              2.699          4.825     1
# ...

# %%
data.describe()
# Out:
#              Area   Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# count  199.000000  199.000000   199.000000     199.000000    199.000000
# mean    14.918744   14.595829     0.870811       5.643151      3.265533
# std      2.919976    1.310445     0.023320       0.443593      0.378322
# min     10.590000   12.410000     0.808100       4.899000      2.630000
# 25%     12.330000   13.470000     0.857100       5.267000      2.954500
# 50%     14.430000   14.370000     0.873400       5.541000      3.245000
# 75%     17.455000   15.805000     0.886800       6.002000      3.564500
# max     21.180000   17.250000     0.918300       6.675000      4.033000
#
#        Asymmetry.Coeff  Kernel.Groove        Type
# count       199.000000     199.000000  199.000000
# mean          3.699217       5.420653    1.994975
# std           1.471102       0.492718    0.813382
# min           0.765100       4.519000    1.000000
# 25%           2.570000       5.046000    1.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             199 non-null    float64
#  1   Perimeter        199 non-null    float64
#  2   Compactness      199 non-null    float64
#  3   Kernel.Length    199 non-null    float64
#  4   Kernel.Width     199 non-null    float64
#  5   Asymmetry.Coeff  199 non-null    float64
#  6   Kernel.Groove    199 non-null    float64
#  7   Type             199 non-null    int64
# dtypes: float64(7), int64(1)
# memory usage: 12.6 KB

# %%
data.shape
# Out:
# (199, 8)

# %%
data.columns=['Area', 'Perimeter', 'Compactness', 'KernelLength','KernelWidth', 'AsymmetryCoeff','KernelGroove' , 'Category']
data.head()
# Out:
#     Area  Perimeter  Compactness  KernelLength  KernelWidth  AsymmetryCoeff  \
# 0  15.26      14.84       0.8710         5.763        3.312           2.221
# 1  14.88      14.57       0.8811         5.554        3.333           1.018
# 2  14.29      14.09       0.9050         5.291        3.337           2.699
# 3  13.84      13.94       0.8955         5.324        3.379           2.259
# 4  16.14      14.99       0.9034         5.658        3.562           1.355
#
#    KernelGroove  Category
# 0         5.220         1
# 1         4.956         1
# 2         4.825         1
# 3         4.805         1
# 4         5.175         1

# %%
data["Category"].replace({1 :"Kama" , 2 :"Rosa" , 3 :"Canadian"} , inplace = True)
data.head(-5)
# Out:
#       Area  Perimeter  Compactness  KernelLength  KernelWidth  AsymmetryCoeff  \
# 0    15.26      14.84       0.8710         5.763        3.312           2.221
# 1    14.88      14.57       0.8811         5.554        3.333           1.018
# 2    14.29      14.09       0.9050         5.291        3.337           2.699
# 3    13.84      13.94       0.8955         5.324        3.379           2.259
# 4    16.14      14.99       0.9034         5.658        3.562           1.355
# ..     ...        ...          ...           ...          ...             ...
# 189  12.62      13.67       0.8481         5.410        2.911           3.306
# 190  12.76      13.38       0.8964         5.073        3.155           2.828
# 191  12.38      13.44       0.8609         5.219        2.989           5.472
# 192  11.18      12.72       0.8680         5.009        2.810           4.051
# 193  12.37      13.47       0.8567         5.204        2.960           3.919
#
#      KernelGroove  Category
# ...

# %%
import matplotlib.pyplot as plt

# %%
data.Category.value_counts(normalize=True).plot.barh()    
plt.show()    #Plotting the bar graph of percentages seed categories

# %%
fig, ax = plt.subplots(figsize=(10,10)) 
sns.heatmap(data.corr(), annot=True, square=True ,ax=ax, cmap = 'Reds')
plt.show()    #Correlation Matrix

# %%
sns.relplot(x='Perimeter', y='Compactness', hue='Category', data=data);
#ScatterPlot

# %%
sns.boxplot(data.Category, data.Compactness)
#Plotting boxplot of Category for Compactness
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
x= data.drop('Category', axis=1)
x
# Out:
#       Area  Perimeter  Compactness  KernelLength  KernelWidth  AsymmetryCoeff  \
# 0    15.26      14.84       0.8710         5.763        3.312           2.221
# 1    14.88      14.57       0.8811         5.554        3.333           1.018
# 2    14.29      14.09       0.9050         5.291        3.337           2.699
# 3    13.84      13.94       0.8955         5.324        3.379           2.259
# 4    16.14      14.99       0.9034         5.658        3.562           1.355
# ..     ...        ...          ...           ...          ...             ...
# 194  12.19      13.20       0.8783         5.137        2.981           3.631
# 195  11.23      12.88       0.8511         5.140        2.795           4.325
# 196  13.20      13.66       0.8883         5.236        3.232           8.315
# 197  11.84      13.21       0.8521         5.175        2.836           3.598
# 198  12.30      13.34       0.8684         5.243        2.974           5.637
#
#      KernelGroove
# ...

# %%
y= data['Category']
y
# Out:
# 0          Kama
# 1          Kama
# 2          Kama
# 3          Kama
# 4          Kama
#          ...
# 194    Canadian
# 195    Canadian
# 196    Canadian
# 197    Canadian
# 198    Canadian
# Name: Category, Length: 199, dtype: object

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
x_train , x_test , y_train , y_test = train_test_split(x, y, random_state=2, test_size = 0.25)

# %%
model = DecisionTreeClassifier(min_samples_split=50, criterion='gini')

# %%
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(min_samples_split=50)

# %%
y_predict = model.predict(x_test)

# %%
print("The accuracy of the model is: " + str(accuracy_score(y_test, y_predict)*100) + ' %')
# Out:
# The accuracy of the model is: 88.0 %

# %%
import pickle

# %%
filename='model.pkl'
outfile= open(filename, 'wb')
pickle.dump(model, outfile)
outfile.close()
